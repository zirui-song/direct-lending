# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
results = pd.read_csv('/Users/zrsong/MIT Dropbox/Zirui Song/Research Projects/PSW_Nonbank Direct Lending/Data/Raw/batch_jobs/processed/batch_results.csv')

# %%
# Drop rows where lender_type is 'Traditional Banks' (case-insensitive)
filtered = results[~results['lender_type'].str.lower().eq('traditional banks')].copy()

# Sort by lender_type
filtered = filtered.sort_values('lender_type').reset_index(drop=True)

filtered.head()
# Out:
#                         custom_id             accession  \
# 0   loan_631_0000776867-18-000018  0000776867-18-000018
# 1  loan_1833_0000950170-23-060213  0000950170-23-060213
# 2  loan_7951_0001564590-17-004563  0001564590-17-004563
# 3  loan_3430_0001140361-20-017754  0001140361-20-017754
# 4  loan_5749_0001193125-16-637528  0001193125-16-637528
#
#                                        borrower_name  \
# 0                           NSM Insurance Group, LLC
# 1                                   Paragon 28, Inc.
# 2  Xoma Corporation; Xoma (US) LLC; Xoma Commerci...
# 3                               Designer Brands Inc.
# 4                Power Solutions International, Inc.
#
#                                 lender_name  \
# 0                  Ares Capital Corporation
# 1                  Ares Capital Corporation
# 2  Hercules Technology Growth Capital, Inc.
# 3      Sixth Street Specialty Lending, Inc.
# 4               TPG Specialty Lending, Inc.
#
# ...
